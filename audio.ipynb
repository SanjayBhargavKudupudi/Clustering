# %% [markdown]
# <a href="https://colab.research.google.com/github/SanjayBhargavKudupudi/Clustering/blob/main/audio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import librosa
import numpy as np
# Import imagebind llms here (if it supports audio)

# Function to load and preprocess audio
def load_and_preprocess_audio(audio_paths):
    audios = []
    for path in audio_paths:
        audio, sr = librosa.load(path, sr=None)
        # Preprocess the audio - e.g., convert to spectrogram
        # Add your preprocessing steps here
        audios.append(audio)
    return audios

# Function to extract embeddings using imagebind llms
def extract_audio_embeddings(audios):
    # This function should use imagebind llms to extract embeddings
    # Replace the below line with the actual embedding extraction code
    embeddings = [np.random.rand(128) for _ in audios]
    return np.array(embeddings)

# Load your audio files (replace with actual paths)
audio_paths = ['/content/drive/MyDrive/sound/Chicago - British Woman_speed_3.wav','/content/drive/MyDrive/sound/Chicago - British Woman_speed_4.wav','/content/drive/MyDrive/sound/Chicago - British Woman_speed_0.wav' ,'/content/drive/MyDrive/sound/Chicago - British Woman_noise_0.wav']
audios = load_and_preprocess_audio(audio_paths)

# Extract embeddings
embeddings = extract_audio_embeddings(audios)

# Further analysis and visualization (based on your specific needs)
# For example, you can use PCA for dimensionality reduction
# and visualize the embeddings in a 2D space

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Function for dimensionality reduction using PCA
def reduce_dimensions(embeddings, n_components=2):
    pca = PCA(n_components=n_components)
    reduced_embeddings = pca.fit_transform(embeddings)
    return reduced_embeddings

# Reduce the dimensions of the embeddings
reduced_embeddings = reduce_dimensions(embeddings)

# Simple scatter plot for visualization
plt.figure(figsize=(8, 6))
plt.scatter(reduced_embeddings[:, 0], reduced_embeddings[:, 1])
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.title('2D Visualization of Audio Embeddings')
plt.show()
